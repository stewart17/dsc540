# %% [markdown]
# # Weeks 7 & 8 Exercises

# %%
import pandas as pd

# %% [markdown]
# ## Ch. 7 Transformations

# %%
# import data and view it
candy = pd.read_excel("CANDYDATA.xlsx")
candy
# Out:
# C:\Users\Stewart\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                  ITEM    JOY  DESPAIR  \
# 0                             York Peppermint Patties    634       78
# 1                                Whole Wheat anything     21      419
# 2                                         White Bread     15      473
# 3                                             Vicodin    323      210
# 4                                                Twix    770       26
# ..                                                ...    ...      ...
# 82                                        Black Jacks     34      252
# 83                           Any full-sized candy bar    828       13
# 84  Anonymous brown globs that come in black and o...    120      663
# 85                                      100 Grand Bar    570       34
# ...

# %% [markdown]
# ##### Transformation 1: Dropping Duplicates

# %%
# drop duplicates
candy.drop_duplicates(inplace=True)
candy
# Out:
#                                                  ITEM    JOY  DESPAIR  \
# 0                             York Peppermint Patties    634       78
# 1                                Whole Wheat anything     21      419
# 2                                         White Bread     15      473
# 3                                             Vicodin    323      210
# 4                                                Twix    770       26
# ..                                                ...    ...      ...
# 82                                        Black Jacks     34      252
# 83                           Any full-sized candy bar    828       13
# 84  Anonymous brown globs that come in black and o...    120      663
# 85                                      100 Grand Bar    570       34
# 86                                                NaN  26204    17563
#
#     NET FEELIES  NET CLOUT  DESPAIR (NEG)
# 0         556.0   1.639118          -78.0
# ...

# %% [markdown]
# ##### Transformation 2: Filter Out Missing Data

# %%
# filter out missing data
cleaned = candy.dropna()
cleaned
# Out:
#                                                  ITEM  JOY  DESPAIR  \
# 0                             York Peppermint Patties  634       78
# 1                                Whole Wheat anything   21      419
# 2                                         White Bread   15      473
# 3                                             Vicodin  323      210
# 4                                                Twix  770       26
# ..                                                ...  ...      ...
# 81                                            Bonkers   31       99
# 82                                        Black Jacks   34      252
# 83                           Any full-sized candy bar  828       13
# 84  Anonymous brown globs that come in black and o...  120      663
# 85                                      100 Grand Bar  570       34
#
#     NET FEELIES  NET CLOUT  DESPAIR (NEG)
# 0         556.0   1.639118          -78.0
# 1        -398.0   1.012938         -419.0
# ...

# %% [markdown]
# ## Ch. 8 Transformations

# %% [markdown]
# #### Reshape Data to Long Format

# %%
# melt data to long format
melted = pd.melt(cleaned, ["ITEM"])
melted
# Out:
#                                                   ITEM       variable  value
# 0                              York Peppermint Patties            JOY  634.0
# 1                                 Whole Wheat anything            JOY   21.0
# 2                                          White Bread            JOY   15.0
# 3                                              Vicodin            JOY  323.0
# 4                                                 Twix            JOY  770.0
# ..                                                 ...            ...    ...
# 425                                            Bonkers  DESPAIR (NEG)  -99.0
# 426                                        Black Jacks  DESPAIR (NEG) -252.0
# 427                           Any full-sized candy bar  DESPAIR (NEG)  -13.0
# 428  Anonymous brown globs that come in black and o...  DESPAIR (NEG) -663.0
# 429                                      100 Grand Bar  DESPAIR (NEG)  -34.0
#
# [430 rows x 3 columns]

# %% [markdown]
# #### Reshape Data

# %%
# stack data
hierarchy = cleaned.stack()
hierarchy
# Out:
# 0   ITEM             York Peppermint Patties
#     JOY                                  634
#     DESPAIR                               78
#     NET FEELIES                        556.0
#     NET CLOUT                       1.639118
#                               ...
# 85  JOY                                  570
#     DESPAIR                               34
#     NET FEELIES                        536.0
#     NET CLOUT                       1.390488
#     DESPAIR (NEG)                      -34.0
# Length: 516, dtype: object

# %% [markdown]
# ## Chapter 10 Transformations

# %% [markdown]
# ##### Split/Apply/Combine

# %%
# find top net feelies
def find_max(df, n=5, column="NET FEELIES"):
    return df.sort_values(by=column)[-n:]

# %%
# find top feelies according to item
cleaned.groupby("NET FEELIES").apply(find_max)
# Out:
#                                                              ITEM  JOY  \
# NET FEELIES
# -592.0      73  Candy that is clearly just the stuff given out...   29
# -565.0      77                                  Broken glow stick   14
# -543.0      67                                Dental paraphenalia   43
#             84  Anonymous brown globs that come in black and o...  120
# -538.0      79                                     Box’o’ Raisins   47
# ...                                                           ...  ...
#  712.0      13                                           Snickers  739
#  744.0      4                                                Twix  770
#  815.0      83                           Any full-sized candy bar  828
#  879.0      47                                            Kit Kat  894
#  936.0      23                         Reese’s Peanut Butter Cups  983
#
#                 DESPAIR  NET FEELIES  NET CLOUT  DESPAIR (NEG)
# NET FEELIES
# ...

# %% [markdown]
# #### Cross Tab

# %%
# load candy survey in full
candy2 = pd.read_csv("candyhierarchy2017(1).csv", encoding ="iso-8859-1")
candy2
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773            NaN        NaN     NaN         NaN
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                                 NaN                NaN
# 1                                  NM                MEH
# ...

# %%
# crosstab gender with 100 Grand Bar
pd.crosstab(candy2["Q2: GENDER"], candy2["Q6 | 100 Grand Bar"])
# Out:
# Q6 | 100 Grand Bar  DESPAIR  JOY  MEH
# Q2: GENDER
# Female                   39  265  279
# I'd rather not say        3   33   24
# Male                     41  564  436
# Other                     2    8   12

# %% [markdown]
# ## Chapter 11 Transformations

# %% [markdown]
# #### Generate Date Range

# %%
candy2015 = pd.read_excel("CANDY-HIERARCHY-2015-SURVEY-Responses.xlsx")
candy2015
# Out:
#                    Timestamp How old are you?  \
# 0    2015-10-23 08:46:20.451             35.0
# 1    2015-10-23 08:46:51.583             41.0
# 2    2015-10-23 08:47:34.285             33.0
# 3    2015-10-23 08:47:58.964             31.0
# 4    2015-10-23 08:48:11.719             30.0
# ...                      ...              ...
# 5625 2015-10-31 05:23:40.526             50.0
# 5626 2015-10-31 05:29:26.937             43.0
# 5627 2015-10-31 06:13:29.083             35.0
# 5628 2015-10-31 06:26:52.566             38.0
# 5629 2015-10-31 06:41:31.904             44.0
#
#      Are you going actually going trick or treating yourself?  [Butterfinger]  \
# 0                                                    No                   JOY
# 1                                                    No                   JOY
# 2                                                    No               DESPAIR
# 3                                                    No                   JOY
# ...

# %%
# generate data range 
half_week = pd.date_range("2015-10-23", "2015-10-26")
half_week
# Out:
# DatetimeIndex(['2015-10-23', '2015-10-24', '2015-10-25', '2015-10-26'], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# #### Period Frequency Conversion

# %%
candy2016 = pd.read_excel("BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx")
candy2016
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %%
# create time period for october as hours
period = pd.Period("2016-10", "H")
# Out:
# Period('2016-10-01 00:00', 'H')

# %%
# convert period to minutely frequency
period.asfreq("T")
# Out:
# Period('2016-10-01 00:59', 'T')
